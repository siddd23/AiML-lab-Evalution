# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
main = pd.read_csv('/home/shubham/home/Untitled Folder/House_Rent_Dataset.csv')
main
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]

# %%
main_shuffled = main.sample(frac=1,random_state=42) 
main_shuffled
# Out:
#        Posted On  BHK   Rent  Size             Floor    Area Type  \
# 1566  2022-06-23    2  16000  1100        2 out of 4   Super Area
# 3159  2022-05-12    2  12000   800        2 out of 3   Super Area
# 538   2022-05-10    2  28000   518       5 out of 12  Carpet Area
# 2630  2022-06-08    3   8000  1500        1 out of 1  Carpet Area
# 4418  2022-07-06    3  46000  2235  Ground out of 10  Carpet Area
# ...          ...  ...    ...   ...               ...          ...
# 4426  2022-06-29    3  25000  1500        1 out of 2  Carpet Area
# 466   2022-06-13    3  20000  1200        3 out of 3   Super Area
# 3092  2022-07-06    2  20000   800      13 out of 17  Carpet Area
# 3772  2022-05-17    3  85000  3500   Ground out of 1  Carpet Area
# 860   2022-06-20    1  25000   450        5 out of 7  Carpet Area
#
#                       Area Locality       City Furnishing Status  \
# 1566  Jaya Nagar Block 7, Jayanagar  Bangalore       Unfurnished
# 3159               Manikandan Nagar    Chennai         Furnished
# 538                    Bhandup West     Mumbai    Semi-Furnished
# 2630           Cherlopalli TIRUPATI      Delhi       Unfurnished
# 4418                     Gachibowli  Hyderabad       Unfurnished
# ...                             ...        ...               ...
# 4426    Ayodhya Nagar, Quthbullapur  Hyderabad    Semi-Furnished
# 466                       Bansdroni    Kolkata       Unfurnished
# 3092                     Vadapalani    Chennai    Semi-Furnished
# 3772                        T Nagar    Chennai    Semi-Furnished
# 860                   Goregaon West     Mumbai    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 1566  Bachelors/Family         2    Contact Owner
# 3159  Bachelors/Family         2    Contact Owner
# 538   Bachelors/Family         2    Contact Owner
# 2630  Bachelors/Family         3    Contact Owner
# 4418            Family         5    Contact Agent
# ...                ...       ...              ...
# 4426            Family         3    Contact Owner
# 466   Bachelors/Family         2    Contact Owner
# 3092            Family         2    Contact Agent
# 3772  Bachelors/Family         3    Contact Agent
# 860          Bachelors         2    Contact Agent
#
# [4746 rows x 12 columns]

# %%
test = main_shuffled.tail(1000)
test
#test data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 2467  2022-05-06    3  40000  1650       1 out of 3  Carpet Area
# 1645  2022-05-27    2  12000   950       1 out of 2   Super Area
# 3417  2022-05-20    2   5000   800  Ground out of 2   Super Area
# 3476  2022-05-09    3  10000  1000       1 out of 8  Carpet Area
# 3941  2022-06-10    4  25000  1815       2 out of 5   Super Area
# ...          ...  ...    ...   ...              ...          ...
# 4426  2022-06-29    3  25000  1500       1 out of 2  Carpet Area
# 466   2022-06-13    3  20000  1200       3 out of 3   Super Area
# 3092  2022-07-06    2  20000   800     13 out of 17  Carpet Area
# 3772  2022-05-17    3  85000  3500  Ground out of 1  Carpet Area
# 860   2022-06-20    1  25000   450       5 out of 7  Carpet Area
#
#                             Area Locality       City Furnishing Status  \
# 2467                   Dakshini Pitampura      Delhi    Semi-Furnished
# 1645                           Nri Layout  Bangalore    Semi-Furnished
# 3417                           Ayappakkam    Chennai       Unfurnished
# 3476  Kelambakkam, Old Mahabalipuram Road    Chennai    Semi-Furnished
# 3941                       Old Bowenpally  Hyderabad    Semi-Furnished
# ...                                   ...        ...               ...
# 4426          Ayodhya Nagar, Quthbullapur  Hyderabad    Semi-Furnished
# 466                             Bansdroni    Kolkata       Unfurnished
# 3092                           Vadapalani    Chennai    Semi-Furnished
# 3772                              T Nagar    Chennai    Semi-Furnished
# 860                         Goregaon West     Mumbai    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 2467  Bachelors/Family         2    Contact Owner
# 1645  Bachelors/Family         2    Contact Owner
# 3417  Bachelors/Family         2    Contact Owner
# 3476  Bachelors/Family         3    Contact Owner
# 3941  Bachelors/Family         3    Contact Owner
# ...                ...       ...              ...
# 4426            Family         3    Contact Owner
# 466   Bachelors/Family         2    Contact Owner
# 3092            Family         2    Contact Agent
# 3772  Bachelors/Family         3    Contact Agent
# 860          Bachelors         2    Contact Agent
#
# [1000 rows x 12 columns]

# %%
training = main_shuffled.drop(test.index)
training
# Out:
#        Posted On  BHK    Rent  Size             Floor    Area Type  \
# 1566  2022-06-23    2   16000  1100        2 out of 4   Super Area
# 3159  2022-05-12    2   12000   800        2 out of 3   Super Area
# 538   2022-05-10    2   28000   518       5 out of 12  Carpet Area
# 2630  2022-06-08    3    8000  1500        1 out of 1  Carpet Area
# 4418  2022-07-06    3   46000  2235  Ground out of 10  Carpet Area
# ...          ...  ...     ...   ...               ...          ...
# 1854  2022-05-11    2    8900  1100        1 out of 2   Super Area
# 4248  2022-06-22    2   12500  1200        2 out of 5   Super Area
# 2872  2022-05-30    2   20000   950        2 out of 3  Carpet Area
# 3030  2022-05-12    2   14000  1000        1 out of 3   Super Area
# 1205  2022-07-09    3  120000  1130        3 out of 7  Carpet Area
#
#                                         Area Locality       City  \
# 1566                    Jaya Nagar Block 7, Jayanagar  Bangalore
# 3159                                 Manikandan Nagar    Chennai
# 538                                      Bhandup West     Mumbai
# 2630                             Cherlopalli TIRUPATI      Delhi
# 4418                                       Gachibowli  Hyderabad
# ...                                               ...        ...
# 1854                                    Sarjapur Road  Bangalore
# 4248                                         Kompally  Hyderabad
# 2872  Geeta Colony PRWS Block 3 And 7, Rajgarh Colony      Delhi
# 3030                             Kanathur Reddikuppam    Chennai
# 1205                                      Bandra West     Mumbai
#
#      Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 1566       Unfurnished  Bachelors/Family         2    Contact Owner
# 3159         Furnished  Bachelors/Family         2    Contact Owner
# 538     Semi-Furnished  Bachelors/Family         2    Contact Owner
# 2630       Unfurnished  Bachelors/Family         3    Contact Owner
# 4418       Unfurnished            Family         5    Contact Agent
# ...                ...               ...       ...              ...
# 1854    Semi-Furnished  Bachelors/Family         2    Contact Owner
# 4248    Semi-Furnished  Bachelors/Family         2    Contact Owner
# 2872    Semi-Furnished  Bachelors/Family         2    Contact Owner
# 3030       Unfurnished  Bachelors/Family         2    Contact Owner
# 1205    Semi-Furnished  Bachelors/Family         3    Contact Agent
#
# [3746 rows x 12 columns]

# %%
train = training.sample(frac=0.8,random_state=42)
train
# Out:
#        Posted On  BHK   Rent  Size                    Floor    Area Type  \
# 46    2022-05-20    2   4600   400               3 out of 3  Carpet Area
# 518   2022-06-08    2  45000  1320  Lower Basement out of 2   Super Area
# 3930  2022-07-06    3  75000  2395             14 out of 17  Carpet Area
# 201   2022-06-24    1  10000   700               1 out of 2  Carpet Area
# 3520  2022-07-10    3  65000  1444             11 out of 14   Super Area
# ...          ...  ...    ...   ...                      ...          ...
# 2224  2022-06-27    1   6500   450          Ground out of 2  Carpet Area
# 2293  2022-05-23    1   4000   250          Ground out of 2   Super Area
# 1814  2022-06-22    2   9750   575          Ground out of 2  Carpet Area
# 1950  2022-05-23    2  12000   650               2 out of 4   Super Area
# 4037  2022-05-06    2  10000  1090               2 out of 4   Super Area
#
#                        Area Locality       City Furnishing Status  \
# 46                            Behala    Kolkata    Semi-Furnished
# 518                       Ballygunge    Kolkata         Furnished
# 3930   Vittal Rao Nagar, Hitech City  Hyderabad    Semi-Furnished
# 201                            Garia    Kolkata       Unfurnished
# 3520                    Nungambakkam    Chennai    Semi-Furnished
# ...                              ...        ...               ...
# 2224          Garden City University  Bangalore    Semi-Furnished
# 2293                     Vijayanagar  Bangalore       Unfurnished
# 1814                        Varanasi  Bangalore    Semi-Furnished
# 1950                    Bommanahalli  Bangalore    Semi-Furnished
# 4037  Hyder Shah Kote, Chevella Road  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 46           Bachelors         1    Contact Owner
# 518   Bachelors/Family         2    Contact Owner
# 3930            Family         3    Contact Agent
# 201          Bachelors         1    Contact Owner
# 3520         Bachelors         3    Contact Agent
# ...                ...       ...              ...
# 2224  Bachelors/Family         1    Contact Owner
# 2293  Bachelors/Family         1    Contact Owner
# 1814         Bachelors         2    Contact Owner
# 1950  Bachelors/Family         2    Contact Owner
# 4037  Bachelors/Family         2    Contact Owner
#
# [2997 rows x 12 columns]

# %%
validation = training.drop(train.index)
validation
# Out:
#        Posted On  BHK    Rent  Size             Floor    Area Type  \
# 3159  2022-05-12    2   12000   800        2 out of 3   Super Area
# 4418  2022-07-06    3   46000  2235  Ground out of 10  Carpet Area
# 4080  2022-06-18    2   12000   500        1 out of 2   Super Area
# 3792  2022-07-06    4  140000  2600        2 out of 2  Carpet Area
# 2323  2022-07-05    3   60000  1850        3 out of 3  Carpet Area
# ...          ...  ...     ...   ...               ...          ...
# 4727  2022-06-28    3   30000   214        2 out of 2   Super Area
# 3878  2022-06-28    4   75000  3800       3 out of 10  Carpet Area
# 2360  2022-05-05    3   24000  1400        2 out of 4   Super Area
# 3502  2022-06-29    3   60000  1800        9 out of 9   Super Area
# 3030  2022-05-12    2   14000  1000        1 out of 3   Super Area
#
#                               Area Locality       City Furnishing Status  \
# 3159                       Manikandan Nagar    Chennai         Furnished
# 4418                             Gachibowli  Hyderabad       Unfurnished
# 4080            Saidabad Colony, Sayeedabad  Hyderabad         Furnished
# 3792                           Ranjith Road    Chennai    Semi-Furnished
# 2323                               Halasuru  Bangalore         Furnished
# ...                                     ...        ...               ...
# 4727                          Jubilee Hills  Hyderabad         Furnished
# 3878      Financial District, Nanakram Guda  Hyderabad    Semi-Furnished
# 2360  Jalahalli, Jalahalli, Outer Ring Road  Bangalore    Semi-Furnished
# 3502                          in Saligramam    Chennai    Semi-Furnished
# 3030                   Kanathur Reddikuppam    Chennai       Unfurnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 3159  Bachelors/Family         2    Contact Owner
# 4418            Family         5    Contact Agent
# 4080  Bachelors/Family         2    Contact Owner
# 3792  Bachelors/Family         4    Contact Agent
# 2323  Bachelors/Family         3    Contact Owner
# ...                ...       ...              ...
# 4727         Bachelors         4    Contact Owner
# 3878  Bachelors/Family         4    Contact Agent
# 2360  Bachelors/Family         3    Contact Owner
# 3502         Bachelors         3    Contact Agent
# 3030  Bachelors/Family         2    Contact Owner
#
# [749 rows x 12 columns]

# %% [markdown]
# number of rows in training, validation and test sets, along with the structure, datatypes and value counts of the dataframes.

# %%
print(train.dtypes)
print("The number of rows and columns are :",len(train),",",len(train.columns))
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type            object
# Area Locality        object
# City                 object
# Furnishing Status    object
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object
# The number of rows and columns are : 2997 , 12

# %%
print(test.dtypes)
print("The number of rows and columns are :",len(test),",",len(test.columns))
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type            object
# Area Locality        object
# City                 object
# Furnishing Status    object
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object
# The number of rows and columns are : 1000 , 12

# %%
print(validation.dtypes)
print("The number of rows and columns are :",len(validation),",",len(validation.columns))
# Out:
# Posted On            object
# BHK                   int64
# Rent                  int64
# Size                  int64
# Floor                object
# Area Type            object
# Area Locality        object
# City                 object
# Furnishing Status    object
# Tenant Preferred     object
# Bathroom              int64
# Point of Contact     object
# dtype: object
# The number of rows and columns are : 749 , 12

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# Analyse the data and identify which columns are not relevant for house rent prediction task. Drop those columns from the dataframes.

# %%
train.head(5)
# Out:
#        Posted On  BHK   Rent  Size                    Floor    Area Type  \
# 46    2022-05-20    2   4600   400               3 out of 3  Carpet Area
# 518   2022-06-08    2  45000  1320  Lower Basement out of 2   Super Area
# 3930  2022-07-06    3  75000  2395             14 out of 17  Carpet Area
# 201   2022-06-24    1  10000   700               1 out of 2  Carpet Area
# 3520  2022-07-10    3  65000  1444             11 out of 14   Super Area
#
#                       Area Locality       City Furnishing Status  \
# 46                           Behala    Kolkata    Semi-Furnished
# 518                      Ballygunge    Kolkata         Furnished
# 3930  Vittal Rao Nagar, Hitech City  Hyderabad    Semi-Furnished
# 201                           Garia    Kolkata       Unfurnished
# 3520                   Nungambakkam    Chennai    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 46           Bachelors         1    Contact Owner
# 518   Bachelors/Family         2    Contact Owner
# 3930            Family         3    Contact Agent
# 201          Bachelors         1    Contact Owner
# 3520         Bachelors         3    Contact Agent

# %%
train.drop(['Posted On','Area Type','Tenant Preferred','Point of Contact'],axis=1)
# Out:
#       BHK   Rent  Size                    Floor  \
# 46      2   4600   400               3 out of 3
# 518     2  45000  1320  Lower Basement out of 2
# 3930    3  75000  2395             14 out of 17
# 201     1  10000   700               1 out of 2
# 3520    3  65000  1444             11 out of 14
# ...   ...    ...   ...                      ...
# 2224    1   6500   450          Ground out of 2
# 2293    1   4000   250          Ground out of 2
# 1814    2   9750   575          Ground out of 2
# 1950    2  12000   650               2 out of 4
# 4037    2  10000  1090               2 out of 4
#
#                        Area Locality       City Furnishing Status  Bathroom
# 46                            Behala    Kolkata    Semi-Furnished         1
# 518                       Ballygunge    Kolkata         Furnished         2
# 3930   Vittal Rao Nagar, Hitech City  Hyderabad    Semi-Furnished         3
# 201                            Garia    Kolkata       Unfurnished         1
# 3520                    Nungambakkam    Chennai    Semi-Furnished         3
# ...                              ...        ...               ...       ...
# 2224          Garden City University  Bangalore    Semi-Furnished         1
# 2293                     Vijayanagar  Bangalore       Unfurnished         1
# 1814                        Varanasi  Bangalore    Semi-Furnished         2
# 1950                    Bommanahalli  Bangalore    Semi-Furnished         2
# 4037  Hyder Shah Kote, Chevella Road  Hyderabad       Unfurnished         2
#
# [2997 rows x 8 columns]

# %% [markdown]
# Check for missing values and logically impute the dataset.

# %%
print("FOR NA VALUE:\n",train.isna().sum(),'\n')
print("FOR NULL VALUE:\n",train.isnull().sum(),'\n')
print("There is no null value and no Na Values, therefore there is no need of logical imputation")
# Out:
# FOR NA VALUE:
#  Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64
#
# FOR NULL VALUE:
#  Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64
#
# There is no null value and no Na Values, therefore there is no need of logical imputation

# %% [markdown]
# Identify any categorical valued columns (non-numeric) and convert them to numeric.

# %%
train['Furnishing Status'].replace('Semi-Furnished',1).replace('Unfurnished',0).replace('Furnished',2)
# Out:
# 46      1
# 518     2
# 3930    1
# 201     0
# 3520    1
#        ..
# 2224    1
# 2293    0
# 1814    1
# 1950    1
# 4037    0
# Name: Furnishing Status, Length: 2997, dtype: int64

# %% [markdown]
# # Exploratory Analysis (On training set):

# %% [markdown]
# Plot the house rents against the dependent variable of “size”. See if there is a uniform linear trend between the dependent and independent variables. Make accurate axis and legend. Save the plot in a png file.

# %%
df = train[['Size','Rent']]
df=df.tail(1000)
df.plot(kind='scatter',x='Size',y='Rent',color='red')
plt.title('Rent vs Size')
plt.legend(["Rent for the x Size Room"])
plt.show()

# %% [markdown]
# Find average rent prices in different cities and report which city has the highest average rent.

# %%
df1 = train[['Rent','City']]
m=df1.groupby(["City"],sort=True)['Rent'].mean()
print(m)
print(m.max())
m.plot(color='red')
plt.title("Average Rent of Cities")
plt.ylabel("Average Rent")
# Out:
# City
# Bangalore    27585.763060
# Chennai      22145.766372
# Delhi        30994.748031
# Hyderabad    20448.101266
# Kolkata      11909.943953
# Mumbai       85821.845907
# Name: Rent, dtype: float64
# 85821.84590690209
# Text(0, 0.5, 'Average Rent')

# %% [markdown]
# # Regression:

# %% [markdown]
# Train a linear regression model on the training set partition by taking only one dependent variable of
# “size”. Calculate the error on the validation set.

# %%
train_part = train[['BHK','Rent','Bathroom']]
train_part
# Out:
#       BHK   Rent  Bathroom
# 46      2   4600         1
# 518     2  45000         2
# 3930    3  75000         3
# 201     1  10000         1
# 3520    3  65000         3
# ...   ...    ...       ...
# 2224    1   6500         1
# 2293    1   4000         1
# 1814    2   9750         2
# 1950    2  12000         2
# 4037    2  10000         2
#
# [2997 rows x 3 columns]

# %%
model = LinearRegression()

# %%
model.fit(train_part,train['Size'])
# Out:
# LinearRegression()

# %%
test_prediction = model.predict(test[['BHK','Rent','Bathroom']])
df2 = pd.DataFrame(data=test_prediction,columns=["Predicted Size"])
df2 #print test prediction
# Out:
#      Predicted Size
# 0       1243.710957
# 1        933.428892
# 2        928.085563
# 3       1495.771253
# 4       1796.129994
# ..              ...
# 995     1507.221243
# 996     1228.444304
# 997      939.535553
# 998     1553.021204
# 999      654.443466
#
# [1000 rows x 1 columns]

# %%
df3 = train[['Size']].tail(1000)
df3
# Out:
#       Size
# 4518  3400
# 1472   700
# 265    900
# 1461   774
# 2340  2390
# ...    ...
# 2224   450
# 2293   250
# 1814   575
# 1950   650
# 4037  1090
#
# [1000 rows x 1 columns]

# %%
df3Idx=df3.index.values
df2Idx=df2.index.values

# %%
plt.scatter(y=df3['Size'],x=df3Idx,c="pink",linewidths=1,marker="s",edgecolor="red",s=25)
plt.scatter(y=df2['Predicted Size'],x=df2Idx,c="lightblue",linewidths=1,marker="*",edgecolor="blue",s=100)
plt.title("Predicted Size v/s True Size")
plt.legend(['Actual','Predicted'])
plt.xlabel("Index")
plt.ylabel("Size")
plt.show()

# %%
mae = mean_absolute_error(test['Size'],test_prediction)
print("MAE: ",mae)
mse = mean_squared_error(test['Size'],test_prediction)
print("MSE: ",mse)
# Out:
# MAE:  272.2328354422738
# MSE:  184862.6749401498

# %%
rmse = np.sqrt(mse)
print("RMSE: ",rmse)
# Out:
# RMSE:  429.9565965770845

# %% [markdown]
# Plot the model predictions of rent values alongside the actual rent values taken for the validation set.
# Show the legend, axes and color-coded predictions and ground truth for differentiating.

# %%
train_part1 = train[['BHK','Size','Bathroom']]
train_part1
# Out:
#       BHK  Size  Bathroom
# 46      2   400         1
# 518     2  1320         2
# 3930    3  2395         3
# 201     1   700         1
# 3520    3  1444         3
# ...   ...   ...       ...
# 2224    1   450         1
# 2293    1   250         1
# 1814    2   575         2
# 1950    2   650         2
# 4037    2  1090         2
#
# [2997 rows x 3 columns]

# %%
model = LinearRegression()

# %%
model.fit(train_part1,train['Rent'])
# Out:
# LinearRegression()

# %%
test_prediction = model.predict(test[['BHK','Size','Bathroom']])
# print(test_prediction)
df2 = pd.DataFrame(data=test_prediction,columns=["Predicted Rent"])
df2
# Out:
#      Predicted Rent
# 0      54269.754423
# 1      36956.390874
# 2      32291.704281
# 3      62462.549478
# 4      83352.172748
# ..              ...
# 995    78011.504787
# 996    40275.694646
# 997    32291.704281
# 998   140207.326020
# 999    25862.609448
#
# [1000 rows x 1 columns]

# %%
df3=train[['Rent']].tail(1000)
df3
# Out:
#         Rent
# 4518   35000
# 1472   20000
# 265     8000
# 1461   42000
# 2340  120000
# ...      ...
# 2224    6500
# 2293    4000
# 1814    9750
# 1950   12000
# 4037   10000
#
# [1000 rows x 1 columns]

# %%
plt.scatter(y=df3['Rent'],x=df3Idx,c="pink",linewidths=1,marker="s",edgecolor="red",s=25)
plt.scatter(y=df2['Predicted Rent'],x=df2Idx,c="lightblue",linewidths=1,marker="*",edgecolor="blue",s=100)
plt.title("Predicted Rent v/s True Rent")
plt.legend(['Actual','Predicted'])
plt.xlabel("Index")
plt.ylabel("Rent")
plt.show()

# %%
mae = mean_absolute_error(test['Rent'],test_prediction)
print("MAE: ",mae)
mse = mean_squared_error(test['Rent'],test_prediction)
print("MSE: ",mse)
rmse = np.sqrt(mse)
print("RMSE: ",rmse)
# Out:
# MAE:  28960.270109453922
# MSE:  3336988072.683261
# RMSE:  57766.66921922417

# %% [markdown]
# Create a function for calculating the RMSE values for the predictions Vs the actual ground truth rent
# values. RMSE = SQRT( Σ ( (F(xi) - yi)2)/N ), Here F(x) are the prediction values, N are the number of rows.

# %%
RMSE = np.sqrt(mse)
RMSE
# Out:
# 57766.66921922417

# %% [markdown]
# Train a logistic regression model and check the score for different training iterations. Plot the
# validation results by varying max_iter as 10, 20, 30, ….

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
scaler = StandardScaler()
scaled_X_train= scaler.fit_transform(train_part)
scaled_X_test = scaler.transform(test[['BHK','Rent','Bathroom']])

# %%
modelL = LogisticRegression()
modelL.fit(scaled_X_train,train['Size'])
modelL
# Out:
# /home/shubham/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Lprediction=modelL.predict(scaled_X_test)
Lprediction
# Out:
# array([1000, 1000, 1000, 1500, 1500, 1000,  500, 1000, 1500,  800,  500,
#        1000,  500,  500,  500,  500, 1000, 1800, 1500, 1500,  800, 1000,
#         500, 1000, 1500, 1000, 1000,  500,  500,  500, 2500,  500, 1000,
#        1000, 2800, 1000, 1000, 1500, 1000, 1000, 1000,  500, 1000, 1000,
#        1000,  500, 1000, 1000, 1000, 1000,  500,  500, 1000, 1000, 1500,
#        1000,  500,  500, 1000, 1000,  500,  500, 1000, 1000,  500,  500,
#         800, 1800, 1000, 1500, 1000, 1500, 1000, 2000, 1000, 1500, 1500,
#         800, 1000, 1000, 1500, 1000, 1500,  800, 1800,  500, 1000, 1500,
#        1000, 1000,  500,  500, 1500,  500, 1000, 1100, 1000,  500, 1000,
#        1000, 1000, 1000,  800,  500, 1500, 1000, 1000, 1000, 1000, 1500,
#        1000,  500, 1000, 1000, 2500, 1000,  800,  500, 1500,  500, 1500,
#        1500, 1000,  500, 1500, 1500, 1000,  500, 1000,  500, 1000, 1100,
#        1000, 1000, 1000,  500,  500, 1500, 1800,  500, 1000, 1000, 1500,
#        1500,  500,  500, 1500, 1000, 1000,  500, 2000, 1000,  500, 1000,
#         500, 1000, 1000, 1500, 1000, 4761,  500,  500,  800,  800, 1100,
#         500, 1500, 1000, 1000, 1000, 2500,  500, 2400,  500, 1000, 1500,
#         800, 1000, 1500, 1000, 1500,  500, 1000, 1000,  500, 1000, 1000,
#         500,  500, 1000, 1000, 1000, 1000, 1500, 1000, 1500,  500,  800,
#        1000,  500, 1000, 1000,  500, 1500,  500,  500,  800,  500, 1000,
#        1000, 1000, 1000, 1500,  800,  500, 1500, 1000,  800,  500, 1000,
#        1000,  500, 1000,  500, 1500, 1000, 1000,  500, 2500, 1000, 1000,
#        1000,  500,  500,  500,  800, 1000, 1000,  500, 1000, 1000, 1000,
#        1500, 1000, 1000,  500,  500, 1000,  500, 1000, 1000, 1000,  800,
#        1000, 1000,  800, 1000,  500,  500, 1000, 1000, 1000,  600, 1500,
#         500, 1000,  500,  800, 1000,  800, 3000,  500, 1000,  500,  800,
#        1500,  500,  800, 1500, 1000, 1500,  800, 1500, 1000, 1000,  500,
#        1000, 1000, 1000, 1000,  500, 1000,  500, 1000,  500,  500,  500,
#        1000,  500,  500, 1000, 1000, 1000, 1800, 1500,  500, 1000, 1500,
#         500, 1500,  500,  500,  500,  500, 1500, 1000, 1000,  500, 1000,
#        1000, 1000,  500, 1000, 1000,  500, 1000, 1000, 1000, 1000, 1500,
#         650,  500, 1000, 1000, 1000,  500,  500, 1500,  500, 1000,  500,
#        1000, 1000, 1000, 1000, 1500, 1000, 1000, 1000, 1000, 1000, 1000,
#         500,  500, 1000, 1000,  500, 1000, 1000, 1000, 1500,  500, 1000,
#        1000,  500,  500,  500, 1000,  500, 1500, 1000,  500, 1000, 1000,
#        1500, 1500, 1500, 2800, 1500,  500, 1000,  800, 1000, 1000, 1000,
#         500,  500, 1000,  500, 1500, 1000, 1000,  500, 1500,  500, 2000,
#        1000, 1000, 1000, 1000,  500,  650, 1000,  800, 1000, 2500, 1000,
#         500, 1000,  650, 1000, 1000,  800, 1500, 1500,  800,  500, 1500,
#         500, 1500, 1000, 1000, 1000, 1200, 1000, 1500,  800,  500,  500,
#        1000, 2500, 1000, 1000, 1500, 1100, 1500, 1500,  500, 1000, 1000,
#        1000, 1000, 1000,  500, 1500, 1000, 1500, 1000, 1500, 1000,  650,
#         500, 1000,  500,  800,  800, 1000, 1500,  800, 1500, 1000,  500,
#        1000, 1000, 1000, 1000, 1000, 1000, 1500,  650, 1500, 1800, 1100,
#        1000, 1000, 1500,  800,  500, 1800, 1000,  500, 2400, 1500,  500,
#        1000, 1000,  600, 1000, 1000, 1000, 1000,  800, 1000, 1000,  500,
#        1000, 1500, 1000,  800,  500, 1000, 1000,  800, 1000, 2500,  500,
#         800, 1000, 1000, 1000, 1000, 1000,  800, 1000, 1000, 1000, 2000,
#        2000, 1000, 1000, 1000,  500, 1000,  800, 1800, 1000, 1000, 1000,
#        2500, 1000, 1500, 1500, 1000,  650, 1500, 1000, 1000, 1500, 1000,
#         500, 1500, 1000, 1000, 1000,  600, 1000, 1500, 1000, 1500, 1000,
#         500, 1000, 1000, 1000,  800, 1000, 1000,  650,  800,  500,  500,
#         800, 1500, 1000, 1000,  750, 1500,  800,  800, 1500, 1000, 1000,
#        1000, 1000,  500, 1000, 1000, 2500, 1000, 1000,  800,  500,  500,
#         800,  500, 1800,  800, 1500,  500, 1000, 1000,  500, 1000, 1000,
#         500, 1500, 1000, 1000, 4761,  800, 1000,  500, 1000, 1000, 1500,
#        1000, 1000,  500,  500, 1000, 1000, 1500, 1000, 1000,  800,  500,
#        1000, 1000, 1800, 1000, 1500,  500, 1000, 1000, 1000,  500, 1000,
#        1000,  500, 1000, 1000, 1000, 1500, 1000, 1000,  500, 1000,  500,
#        1000, 1000, 2000,  500,  500,  500,  800, 1000, 1000, 1500,  500,
#         500,  700, 1000, 1000, 1000, 1000,  500, 4761,  500,  500,  500,
#        1500, 1000, 1000, 1000,  500, 1000, 1000, 1000, 1000, 1000, 1500,
#        1000, 1000, 1500, 1000, 2000, 2500,  800, 1000, 1000, 1000,  500,
#        1000,  500, 1000, 1000,  500,  500, 1500, 1000, 1500, 1000,  500,
#        1000, 1000, 1500, 1000, 1500, 1000, 1000,  500,  500, 1100, 1000,
#         500, 1000, 1000, 1500,  500, 1500, 1000,  500,  800,  500, 1000,
#        1000, 2400, 1000,  500, 1000,  500,  800,  500,  800,  500, 1500,
#         800, 1000, 1000, 1500,  800,  650, 1800,  500, 1000, 1000, 1000,
#        1500,  500, 1000, 1000, 1000,  500, 1000, 1000,  500,  800,  500,
#        1000,  500,  800, 1000, 1500,  500,  500, 1000, 1000, 1500,  500,
#         500, 1000, 1000, 1000,  500,  500,  500, 1000, 1000, 1000, 1500,
#        1000, 1000,  800, 2500, 1800, 1500, 1500, 1000, 1500,  800,  500,
#        1000, 1000,  500, 1500,  800, 1000,  500, 1000, 1500, 1500, 1000,
#         800, 1000, 1000, 1500,  500, 1000,  500, 1000, 1000, 2500,  800,
#         600,  500, 1800, 1000,  500, 1000,  800, 1000, 1000, 1500, 1500,
#         600,  800, 1000, 2500,  600,  500, 1000, 1000, 1000, 1000, 1000,
#        1000, 1500,  500, 1000, 1000, 1500, 1000, 1000, 1500, 1000, 1000,
#        1000,  800,  500,  500, 1000,  500, 1000, 1500, 2000, 1000, 1000,
#        1000, 1000, 1000,  500, 2000, 1800, 1000,  500, 1000, 1000, 1000,
#        1000, 1000, 1000,  500, 1000, 1000, 1000,  650, 1000, 1500, 1000,
#         500, 1500, 1000,  500,  500, 1000,  500, 1000, 1000, 1000, 1000,
#        1000,  800, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000,  500,
#         800,  500, 2500,  800, 1000, 1000, 1000, 1000, 1000,  500, 1000,
#        1000, 1000,  500, 1500,  500, 1000, 1500, 1000,  500, 1000,  500,
#         500, 1800, 1000, 1000, 2800, 1500,  800,  800,  500, 1500, 1000,
#        1000,  800,  500, 1000, 1000,  800, 1000, 2500, 1500, 1000, 1000,
#        2800,  500,  500, 1000, 1500, 1500, 1000, 1000,  500, 1500, 1000,
#        1000,  500, 1000,  800, 1000, 1000, 1000,  650,  500,  800, 1000,
#        1000,  800,  500,  500, 2000, 1000, 1500, 1500,  500,  800, 1000,
#        1000,  500,  500,  500, 1000, 1000,  500, 1000, 1000, 1000, 1500,
#         800, 1000, 1000, 1000, 1500, 1500, 1000, 1000, 1000,  500, 1000,
#         800,  500, 1000,  800, 1500, 1500, 1000, 1000, 1500,  500])

# %% [markdown]
# Try to improve accuracy (on validation set) by considering more features and retraining.

# %%
modelL.score(scaled_X_train,train['Size'])
# Out:
# 0.0970970970970971

# %% [markdown]
# Make predictions on the test set by taking 3 of your best models. Report these 3 accuracy values.
