# %%
import pandas as pd
train_df=pd.read_csv('train.csv')
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
r,c=train_df.shape
print("Number of Rows: "+str(r))
print("Number of Columns: "+str(c))
# Out:
# Number of Rows: 891
# Number of Columns: 12

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test_df=pd.read_csv('test.csv')
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
r,c=test_df.shape
print("Number of Rows: "+str(r))
print("Number of Columns: "+str(c))
# Out:
# Number of Rows: 418
# Number of Columns: 11

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# # Data Cleaning

# %%
train_df1=train_df.drop(["PassengerId","Embarked","Parch","Age","Fare"],axis='columns')
train_df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  SibSp            Ticket Cabin
# 0      male      1         A/5 21171   NaN
# ...

# %%
test_df1=test_df.drop(["PassengerId","Embarked","Parch","Age","Fare"],axis='columns')
test_df1
# Out:
#      Pclass                                          Name     Sex  SibSp  \
# 0         3                              Kelly, Mr. James    male      0
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female      1
# 2         2                     Myles, Mr. Thomas Francis    male      0
# 3         3                              Wirz, Mr. Albert    male      0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1
# ..      ...                                           ...     ...    ...
# 413       3                            Spector, Mr. Woolf    male      0
# 414       1                  Oliva y Ocana, Dona. Fermina  female      0
# 415       3                  Saether, Mr. Simon Sivertsen    male      0
# 416       3                           Ware, Mr. Frederick    male      0
# 417       3                      Peter, Master. Michael J    male      1
#
#                  Ticket Cabin
# 0                330911   NaN
# ...

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#total nullvalues in train dataset
train_df.isnull().sum().sum()
# Out:
# 866

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#total nullvalues in test dataset
test_df.isnull().sum().sum()
# Out:
# 414

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_df1["Sex"]= le.fit_transform(train_df["Sex"])
train_df1
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
test_df1["Sex"]= le.fit_transform(test_df["Sex"])
test_df1
# Out:
#      Pclass                                          Name  Sex  SibSp  \
# 0         3                              Kelly, Mr. James    1      0
# 1         3              Wilkes, Mrs. James (Ellen Needs)    0      1
# 2         2                     Myles, Mr. Thomas Francis    1      0
# 3         3                              Wirz, Mr. Albert    1      0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0      1
# ..      ...                                           ...  ...    ...
# 413       3                            Spector, Mr. Woolf    1      0
# 414       1                  Oliva y Ocana, Dona. Fermina    0      0
# 415       3                  Saether, Mr. Simon Sivertsen    1      0
# 416       3                           Ware, Mr. Frederick    1      0
# 417       3                      Peter, Master. Michael J    1      1
#
#                  Ticket Cabin
# 0                330911   NaN
# 1                363272   NaN
# 2                240276   NaN
# ...

# %%
group_by_sex = train_df.groupby('Sex')

survived_by_sex = group_by_sex['Survived'].sum()
survived_by_sex.name = 'Survived'
display(survived_by_sex)

total_by_sex = group_by_sex['Survived'].size()
total_by_sex.name = 'Total'
display(total_by_sex)

survived_total_by_sex = pd.concat([survived_by_sex, total_by_sex], axis=1)
survived_total_by_sex
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64
# Sex
# female    314
# male      577
# Name: Total, dtype: int64
#         Survived  Total
# Sex
# female       233    314
# male         109    577

# %%
import matplotlib.pyplot as plt
x = range(len(survived_total_by_sex.index.values))

ht = survived_total_by_sex.Total
hs = survived_total_by_sex.Survived

pht = plt.bar(x, ht)
phs = plt.bar(x, hs)


plt.xticks(x, survived_total_by_sex.index.values)
plt.xlabel('Sex')
plt.ylabel('Passengers')
plt.title('Survivors by Gender')

plt.legend([pht,phs],['Died', 'Survived'])

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df[train_df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
def age_group(age):
    if age >= 80:
        return '80-89'
    if age >= 70:
        return '70-79'
    if age >= 60:
        return '60-69'
    if age >= 50:
        return '50-59'
    if age >= 40:
        return '40-49'
    if age >= 30:
        return '30-39'
    if age >= 20:
        return '20-29'
    if age >= 10:
        return '10-19'
    if age >= 0:
        return '0-9'
    
train_df['AgeGroup'] = train_df.Age.apply(age_group)
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
age_group_summary = train_df.groupby(['AgeGroup'], as_index=False)['Survived'].agg([np.sum, np.size])
age_group_summary = age_group_summary.rename(columns={'sum':'Survived', 'size':'Total'})
age_group_summary
# Out:
#           Survived  Total
# AgeGroup
# 0-9             38     62
# 10-19           41    102
# 20-29           77    220
# 30-39           73    167
# 40-49           34     89
# 50-59           20     48
# 60-69            6     19
# 70-79            0      6
# 80-89            1      1

# %%
age_group_summary['Died'] = age_group_summary.Total - age_group_summary.Survived
age_group_summary
# Out:
#           Survived  Total  Died
# AgeGroup
# 0-9             38     62    24
# 10-19           41    102    61
# 20-29           77    220   143
# 30-39           73    167    94
# 40-49           34     89    55
# 50-59           20     48    28
# 60-69            6     19    13
# 70-79            0      6     6
# 80-89            1      1     0

# %%
age_group_summary.hist(column='Died');

# %%
childAge=pd.DataFrame(train_df.query("Age <=16"))
child=len(childAge)
Survived=len(childAge.query("Survived == 1"))
notSurvived=len(childAge.query("Survived == 0 "))
print("Number of children - " , child )
print("Numbers of survival - " , Survived)
print("Number of Deaths - " ,notSurvived)
# Out:
# Number of children -  100
# Numbers of survival -  55
# Number of Deaths -  45

# %%
df = pd.DataFrame({'Childern': child, 'Survived': Survived,'NotSurvived':notSurvived},index=['Passenger'])
ax = df.plot.bar(figsize=(8,6),rot=1)

# %%
import seaborn as sns
import scipy.stats as stats

# %%
sns.kdeplot(data=train_df['Fare'], color = 'red')
plt.xlim([0,30])
              
plt.grid(True, linestyle='dashdot')     
plt.show()

# %%
train_df['Fare'].mean()
fare=train_df['Fare']
plt.hist(fare,bins=[0,20,100,300,600],edgecolor="black",label='Age Group')
plt.legend()
plt.xlabel="Age Group"
plt.ylabel="Number of Passengar"
plt.show()

# %%
pd = train_df.query("Survived == 0")
#Survived = 0 represents the people who died.
pd=pd[['Fare','Survived']].copy()
pd
pd['Fare'].plot.hist(  rwidth = 0.6 )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
morefare = train_df.query('Fare>=100')
moreandsur = train_df.query('Survived ==1 and Fare>=100')
percentage= (len(moreandsur)/len(morefare))*100
print(percentage," % of the passengers survived after paying more than 100$.")
print("its looking biased. ")
# Out:
# 73.58490566037736  % of the passengers survived after paying more than 100$.
# its looking biased.

# %%
import re
count=0
for i in train_df['Name']:
    if(re.findall("Mrs", i)):
        count=count+1
print("The Number of married couples were:",count)
# Out:
# The Number of married couples were: 129
